# %%
from pathlib import Path
import os
import json

import numpy as np
import pandas as pd


def read_json(path):
    with open(path, "r") as f:
        return json.load(f)


root_dir = Path("/home/carlyn.1/dna-trait-analysis/tmp/osc_edit_plots")
for root, dirs, files in os.walk(root_dir):
    for f in files:
        if f.endswith("json"):
            parts = f.split(".")[0].split("_")
            sp, wing, *color_parts = parts
            if len(color_parts) == 2:
                color = "_".join(color_parts)
            else:
                color = color_parts[0]
            data = read_json(Path(root, f))

            group_data = []
            for chromosome in range(1, 22):
                chrom_data = data[str(chromosome)]
                ws = chrom_data["window_size"]
                nom_pos = chrom_data["nominal_positions"]
                real_positions = chrom_data["real_position_metadata"]
                attributions = chrom_data["attributions"]
                AA = attributions["test"]["AA"]
                Aa = attributions["test"]["Aa/aA"]
                aa = attributions["test"]["aa"]
                zeroed = attributions["test"]["zero-out"]
                row_length = len(AA["means"])

                new_data = np.stack(
                    [
                        np.array([sp] * row_length),  # Species
                        np.array([wing] * row_length),  # wing
                        np.array([color] * row_length),  # color
                        np.array([chromosome] * row_length),  # Chromosome
                        np.array([ws] * row_length),  # window size
                        np.array(nom_pos),  # nominal position
                        np.array(real_positions)[:, 0],  # scaffold
                        np.array(real_positions)[:, 1],  # real position
                        np.array(AA["means"]),
                        np.array(AA["stds"]),
                        np.array(Aa["means"]),
                        np.array(Aa["stds"]),
                        np.array(aa["means"]),
                        np.array(aa["stds"]),
                        np.array(zeroed["means"]),
                        np.array(zeroed["stds"]),
                    ],
                    axis=1,
                )

                group_data.append(new_data)

            group_data = np.concatenate(group_data)
            df = pd.DataFrame(
                group_data,
                columns=[
                    "species",
                    "wing",
                    "color",
                    "chromosome",
                    "window_size",
                    "nominal_position",
                    "scaffold",
                    "real_position",
                    "AA_mean",
                    "AA_std",
                    "Aa_aA_mean",
                    "Aa_aA_std",
                    "aa_mean",
                    "aa_std",
                    "zeroed_mean",
                    "zeroed_std",
                ],
            )

            new_fn = Path(root_dir, f.split(".")[0] + ".csv")
            df.to_csv(new_fn)

            group_data = []
# Species, wing, color, chromosome, window size, nominal position, scaffold, real_position, AA mean, AA std, ...
# Out:
# erato forewings color_1 1
# erato forewings color_1 2
# erato forewings color_1 3
# erato forewings color_1 4
# erato forewings color_1 5
# erato forewings color_1 6
# erato forewings color_1 7
# erato forewings color_1 8
# erato forewings color_1 9
# erato forewings color_1 10
# erato forewings color_1 11
# erato forewings color_1 12
# erato forewings color_1 13
# erato forewings color_1 14
# erato forewings color_1 15
# erato forewings color_1 16
# erato forewings color_1 17
# erato forewings color_1 18
# erato forewings color_1 19
# erato forewings color_1 20
# erato forewings color_1 21
# erato forewings color_2 1
# erato forewings color_2 2
# erato forewings color_2 3
# erato forewings color_2 4
# erato forewings color_2 5
# erato forewings color_2 6
# erato forewings color_2 7
# erato forewings color_2 8
# erato forewings color_2 9
# erato forewings color_2 10
# erato forewings color_2 11
# erato forewings color_2 12
# erato forewings color_2 13
# erato forewings color_2 14
# erato forewings color_2 15
# erato forewings color_2 16
# erato forewings color_2 17
# erato forewings color_2 18
# erato forewings color_2 19
# erato forewings color_2 20
# erato forewings color_2 21
# erato forewings color_3 1
# erato forewings color_3 2
# erato forewings color_3 3
# erato forewings color_3 4
# erato forewings color_3 5
# erato forewings color_3 6
# erato forewings color_3 7
# erato forewings color_3 8
# erato forewings color_3 9
# erato forewings color_3 10
# erato forewings color_3 11
# erato forewings color_3 12
# erato forewings color_3 13
# erato forewings color_3 14
# erato forewings color_3 15
# erato forewings color_3 16
# erato forewings color_3 17
# erato forewings color_3 18
# erato forewings color_3 19
# erato forewings color_3 20
# erato forewings color_3 21
# erato forewings total 1
# erato forewings total 2
# erato forewings total 3
# erato forewings total 4
# erato forewings total 5
# erato forewings total 6
# erato forewings total 7
# erato forewings total 8
# erato forewings total 9
# erato forewings total 10
# erato forewings total 11
# erato forewings total 12
# erato forewings total 13
# erato forewings total 14
# erato forewings total 15
# erato forewings total 16
# erato forewings total 17
# erato forewings total 18
# erato forewings total 19
# erato forewings total 20
# erato forewings total 21
# erato hindwings color_1 1
# erato hindwings color_1 2
# erato hindwings color_1 3
# erato hindwings color_1 4
# erato hindwings color_1 5
# erato hindwings color_1 6
# erato hindwings color_1 7
# erato hindwings color_1 8
# erato hindwings color_1 9
# erato hindwings color_1 10
# erato hindwings color_1 11
# erato hindwings color_1 12
# erato hindwings color_1 13
# erato hindwings color_1 14
# erato hindwings color_1 15
# erato hindwings color_1 16
# erato hindwings color_1 17
# erato hindwings color_1 18
# erato hindwings color_1 19
# erato hindwings color_1 20
# erato hindwings color_1 21
# erato hindwings color_2 1
# erato hindwings color_2 2
# erato hindwings color_2 3
# erato hindwings color_2 4
# erato hindwings color_2 5
# erato hindwings color_2 6
# erato hindwings color_2 7
# erato hindwings color_2 8
# erato hindwings color_2 9
# erato hindwings color_2 10
# erato hindwings color_2 11
# erato hindwings color_2 12
# erato hindwings color_2 13
# erato hindwings color_2 14
# erato hindwings color_2 15
# erato hindwings color_2 16
# erato hindwings color_2 17
# erato hindwings color_2 18
# erato hindwings color_2 19
# erato hindwings color_2 20
# erato hindwings color_2 21
# erato hindwings color_3 1
# erato hindwings color_3 2
# erato hindwings color_3 3
# erato hindwings color_3 4
# erato hindwings color_3 5
# erato hindwings color_3 6
# erato hindwings color_3 7
# erato hindwings color_3 8
# erato hindwings color_3 9
# erato hindwings color_3 10
# erato hindwings color_3 11
# erato hindwings color_3 12
# erato hindwings color_3 13
# erato hindwings color_3 14
# erato hindwings color_3 15
# erato hindwings color_3 16
# erato hindwings color_3 17
# erato hindwings color_3 18
# erato hindwings color_3 19
# erato hindwings color_3 20
# erato hindwings color_3 21
# erato hindwings total 1
# erato hindwings total 2
# erato hindwings total 3
# erato hindwings total 4
# erato hindwings total 5
# erato hindwings total 6
# erato hindwings total 7
# erato hindwings total 8
# erato hindwings total 9
# erato hindwings total 10
# erato hindwings total 11
# erato hindwings total 12
# erato hindwings total 13
# erato hindwings total 14
# erato hindwings total 15
# erato hindwings total 16
# erato hindwings total 17
# erato hindwings total 18
# erato hindwings total 19
# erato hindwings total 20
# erato hindwings total 21
# melpomene forewings color_1 1
# melpomene forewings color_1 2
# melpomene forewings color_1 3
# melpomene forewings color_1 4
# melpomene forewings color_1 5
# melpomene forewings color_1 6
# melpomene forewings color_1 7
# melpomene forewings color_1 8
# melpomene forewings color_1 9
# melpomene forewings color_1 10
# melpomene forewings color_1 11
# melpomene forewings color_1 12
# melpomene forewings color_1 13
# melpomene forewings color_1 14
# melpomene forewings color_1 15
# melpomene forewings color_1 16
# melpomene forewings color_1 17
# melpomene forewings color_1 18
# melpomene forewings color_1 19
# melpomene forewings color_1 20
# melpomene forewings color_1 21
# melpomene forewings color_2 1
# melpomene forewings color_2 2
# melpomene forewings color_2 3
# melpomene forewings color_2 4
# melpomene forewings color_2 5
# melpomene forewings color_2 6
# melpomene forewings color_2 7
# melpomene forewings color_2 8
# melpomene forewings color_2 9
# melpomene forewings color_2 10
# melpomene forewings color_2 11
# melpomene forewings color_2 12
# melpomene forewings color_2 13
# melpomene forewings color_2 14
# melpomene forewings color_2 15
# melpomene forewings color_2 16
# melpomene forewings color_2 17
# melpomene forewings color_2 18
# melpomene forewings color_2 19
# melpomene forewings color_2 20
# melpomene forewings color_2 21
# melpomene forewings color_3 1
# melpomene forewings color_3 2
# melpomene forewings color_3 3
# melpomene forewings color_3 4
# melpomene forewings color_3 5
# melpomene forewings color_3 6
# melpomene forewings color_3 7
# melpomene forewings color_3 8
# melpomene forewings color_3 9
# melpomene forewings color_3 10
# melpomene forewings color_3 11
# melpomene forewings color_3 12
# melpomene forewings color_3 13
# melpomene forewings color_3 14
# melpomene forewings color_3 15
# melpomene forewings color_3 16
# melpomene forewings color_3 17
# melpomene forewings color_3 18
# melpomene forewings color_3 19
# melpomene forewings color_3 20
# melpomene forewings color_3 21
# melpomene forewings total 1
# melpomene forewings total 2
# melpomene forewings total 3
# melpomene forewings total 4
# melpomene forewings total 5
# melpomene forewings total 6
# melpomene forewings total 7
# melpomene forewings total 8
# melpomene forewings total 9
# melpomene forewings total 10
# melpomene forewings total 11
# melpomene forewings total 12
# melpomene forewings total 13
# melpomene forewings total 14
# melpomene forewings total 15
# melpomene forewings total 16
# melpomene forewings total 17
# melpomene forewings total 18
# melpomene forewings total 19
# melpomene forewings total 20
# melpomene forewings total 21
# melpomene hindwings color_1 1
# melpomene hindwings color_1 2
# melpomene hindwings color_1 3
# melpomene hindwings color_1 4
# melpomene hindwings color_1 5
# melpomene hindwings color_1 6
# melpomene hindwings color_1 7
# melpomene hindwings color_1 8
# melpomene hindwings color_1 9
# melpomene hindwings color_1 10
# melpomene hindwings color_1 11
# melpomene hindwings color_1 12
# melpomene hindwings color_1 13
# melpomene hindwings color_1 14
# melpomene hindwings color_1 15
# melpomene hindwings color_1 16
# melpomene hindwings color_1 17
# melpomene hindwings color_1 18
# melpomene hindwings color_1 19
# melpomene hindwings color_1 20
# melpomene hindwings color_1 21
# melpomene hindwings color_2 1
# melpomene hindwings color_2 2
# melpomene hindwings color_2 3
# melpomene hindwings color_2 4
# melpomene hindwings color_2 5
# melpomene hindwings color_2 6
# melpomene hindwings color_2 7
# melpomene hindwings color_2 8
# melpomene hindwings color_2 9
# melpomene hindwings color_2 10
# melpomene hindwings color_2 11
# melpomene hindwings color_2 12
# melpomene hindwings color_2 13
# melpomene hindwings color_2 14
# melpomene hindwings color_2 15
# melpomene hindwings color_2 16
# melpomene hindwings color_2 17
# melpomene hindwings color_2 18
# melpomene hindwings color_2 19
# melpomene hindwings color_2 20
# melpomene hindwings color_2 21
# melpomene hindwings color_3 1
# melpomene hindwings color_3 2
# melpomene hindwings color_3 3
# melpomene hindwings color_3 4
# melpomene hindwings color_3 5
# melpomene hindwings color_3 6
# melpomene hindwings color_3 7
# melpomene hindwings color_3 8
# melpomene hindwings color_3 9
# melpomene hindwings color_3 10
# melpomene hindwings color_3 11
# melpomene hindwings color_3 12
# melpomene hindwings color_3 13
# melpomene hindwings color_3 14
# melpomene hindwings color_3 15
# melpomene hindwings color_3 16
# melpomene hindwings color_3 17
# melpomene hindwings color_3 18
# melpomene hindwings color_3 19
# melpomene hindwings color_3 20
# melpomene hindwings color_3 21
# melpomene hindwings total 1
# melpomene hindwings total 2
# melpomene hindwings total 3
# melpomene hindwings total 4
# melpomene hindwings total 5
# melpomene hindwings total 6
# melpomene hindwings total 7
# melpomene hindwings total 8
# melpomene hindwings total 9
# melpomene hindwings total 10
# melpomene hindwings total 11
# melpomene hindwings total 12
# melpomene hindwings total 13
# melpomene hindwings total 14
# melpomene hindwings total 15
# melpomene hindwings total 16
# melpomene hindwings total 17
# melpomene hindwings total 18
# melpomene hindwings total 19
# melpomene hindwings total 20
# melpomene hindwings total 21
